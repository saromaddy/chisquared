# %%
#importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Degree of Freedom - (column-1) * (row-1)

# %%
df = 2  # degrees of freedom _ chosen for our class
data = np.random.chisquare(df, 1000) # generated chisquared data from a random distribution with the degree 2

# %%
len(data)
# Out:
# 1000

# %%
data_df = pd.DataFrame(data, columns=['chi_square'])
data_df
# Out:
#      chi_square
# 0      0.056714
# 1      3.296426
# 2      1.616665
# 3      1.371025
# 4      0.209265
# ..          ...
# 995    3.924517
# 996    1.973841
# 997   10.668142
# 998    0.086936
# 999    0.285818
#
# [1000 rows x 1 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data_df['chi_square'], bins=30, kde=True)
plt.title('Chi-Square Distribution with 2 Degrees of Freedom')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
#Null hypothesis - there is no relationship between two variables
#Alternate hypothesis - There is a significant relationship between two variables
